# %% [markdown]
#  1. What are data structures, and why are they important?
#   - Data structures are specialized formats for organizing, storing, and accessing collections of data. They provide efficient ways to manage information based on its characteristics and intended use.
#
#  2. Explain the difference between mutable and immutable data types with examples ?
#   - Mutable data types can be changed after they are created.
# Examples: list, dict, set.
# - Immutable data types cannot be changed after creation.
# Examples: int, float, str, tuple.
#
# 3. What are the main differences between lists and tuples in Python?
#  - | **Feature     | List         | Tuple      ** |
# | ----------- | ------------ | ----------- |
# | Syntax      | `[1, 2, 3]`  | `(1, 2, 3)` |
# | Mutability  | Mutable      | Immutable   |
# | Performance | Slower       | Faster      |
# | Use case    | Dynamic data | Fixed data  |
#
# 4. Describe how dictionaries store data.?
#  - Dictionaries store data in key-value pairs using a hash table. Each key is hashed, and the value is stored in a specific index based on that hash.
#
# 5. Why might you use a set instead of a list in Python?
#   - To eliminate duplicate values.
#    - For faster membership tests.
#   -  When order doesn't matter.
#
# 6. What is a string in Python, and how is it different from a list?
#  - A string is an immutable sequence of characters.
#  - A list is a mutable sequence that can hold multiple data types.
#
# 7. How do tuples ensure data integrity in Python?
#  - Tuples are immutable, which means once created, their contents cannot be changed. This makes them reliable for storing constant or unchanging data.
#
# 8. What is a hash table, and how does it relate to dictionaries in Python?
#  - A hash table is a data structure that maps keys to values using a hash function.
#  - Python dictionaries use hash tables internally to allow constant time access to values via keys.
#
# 9. Can lists contain different data types in Python?
#  - Yes, Python lists are heterogeneous, meaning they can store elements of different types.
#
# 10. Explain why strings are immutable in Python.?
#  - Strings are immutable to:
#       - Improve performance (e.g., memory optimization).
#       - Allow safe reuse in multiple places (interning).
#       - Provide thread safety in concurrent programming.
# 11. What advantages do dictionaries offer over lists for certain tasks?
#  - Faster access using keys (O(1)).
#   - Clear structure with meaningful keys.
#  - Suitable for labeled data like user profiles, configs.
#
# 12. Describe a scenario where using a tuple would be preferable over a list.?
#  - When data should not change, such as:
#       - Geographic coordinates: (28.61, 77.20)
#       - RGB values: (255, 255, 0)
#       - Dictionary keys
#
# 13. How do sets handle duplicate values in Python?
#   - Sets automatically remove duplicates.
#
# 14. How does the “in” keyword work differently for lists and dictionaries?
#   - In lists: Checks values.
#   - In dictionaries: Checks keys only.
#
# 15. Can you modify the elements of a tuple? Explain why or why not?
#   - No, tuples are immutable. You cannot change, add, or delete elements after creation.
#
# 16. What is a nested dictionary, and give an example of its use case?
#    - A nested dictionary is a dictionary within another dictionary.
#     - Use case: Storing hierarchical data, such as student records.
#
# 17. Describe the time complexity of accessing elements in a dictionary ?
#    - Didnt understand the question , kindly explain.
#
# 18. In what situations are lists preferred over dictionaries?
#    - When order matters.
#    - When indexed access is needed.
#    - When duplicate values are acceptable.
#
# 19. Why are dictionaries considered unordered, and how does that affect data retrieval?
#   - Before Python 3.7, dictionaries did not maintain insertion order.
#   - Since Python 3.7, they do preserve order, but are still accessed via keys, not indexes.
#
# 20. Explain the difference between a list and a dictionary in terms of data retrieval. ?
#  - Feature          ||  List     ||     Dictionary
#     - access type - || By index  ||    By Key
#     - Time -        ||  O(1)     ||    O(1)
#     - Use Case -    || Ordered data , Dulpicates || Labeled data , fast lookup

# %%
#Q1  Write a code to create a string with your name and print it ?
name = "Nimisha"
print(name)
# Out:
# Nimisha

# %%
#Q2 Write a code to find the length of the string "Hello World" ?
text = "hello world"
print(len(text))
# Out:
# 11

# %%
#Q3 Write a code to slice the first 3 characters from the string "Python Programming"?
s = "Python Programming"
print(s[:3])
# Out:
# Pyt

# %%
#Q4 Write a code to convert the string "hello" to uppercase ?
word = "hello"
print(word.upper())
# Out:
# HELLO

# %%
#Q5 Write a code to replace the word "apple" with "orange" in the string "I like apple" ?
sentence = "I like apple"
print(sentence.replace("apple", "orange"))
# Out:
# I like orange

# %%
#Q6 Write a code to create a list with numbers 1 to 5 and print it?
numbers = [1, 2, 3, 4, 5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Q7 Write a code to append the number 10 to the list [1, 2, 3, 4] ?
my_list = [1, 2, 3, 4]
my_list.append(10)
print(my_list)
# Out:
# [1, 2, 3, 4, 10]

# %%
#Q8 Write a code to remove the number 3 from the list [1, 2, 3, 4, 5] ?
num_list = [1, 2, 3, 4, 5]
num_list.remove(3)
print(num_list)
# Out:
# [1, 2, 4, 5]

# %%
#Q9 Write a code to access the second element in the list ['a', 'b', 'c', 'd']
letters = ['a', 'b', 'c', 'd']
print(letters[1])
# Out:
# b

# %%
#Q10 Write a code to reverse the list [10, 20, 30, 40, 50] ?
nums = [10, 20, 30, 40, 50]
nums.reverse()
print(nums)
# Out:
# [50, 40, 30, 20, 10]

# %%
#Q11 Write a code to create a tuple with the elements 100, 200, 300 and print it ?
my_tuple = (100,200,300)
print(my_tuple)
# Out:
# (100, 200, 300)

# %%
#Q12 Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow') ?
colors = ('red', 'green', 'blue', 'yellow')
print(colors[-2])
# Out:
# blue

# %%
#Q13 Write a code to find the minimum number in the tuple (10, 20, 5, 15) ?
num = (10 , 20 , 5 , 15)
print(min(num))
# Out:
# 5

# %%
#Q14  Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit') ?
animals = ('dog', 'cat', 'rabbit')
print(animals.index('cat'))
# Out:
# 1

# %%
#Q15 Write a code to create a tuple containing three different fruits and check if "kiwi" is in it ?
fruits = ("apple", "banana", "mango")
print("kiwi" in fruits)
# Out:
# False

# %%
#Q16 Write a code to create a set with the elements 'a', 'b', 'c' and print it ?
my_set = {'a', 'b', 'c'}
print(my_set)
# Out:
# {'c', 'a', 'b'}

# %%
#Q17 Write a code to clear all elements from the set {1, 2, 3, 4, 5} ?
s = {1, 2, 3, 4, 5}
s.clear()
print(s)
# Out:
# set()

# %%
#Q18 Write a code to remove the element 4 from the set {1, 2, 3, 4}?
s = {1, 2, 3, 4}
s.remove(4)
print(s)
# Out:
# {1, 2, 3}

# %%
#Q19  Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5} ?
s = {1, 2, 3, 4}
s.remove(4)
print(s)
# Out:
# {1, 2, 3}

# %%
#Q20 Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4} ?
a = {1, 2, 3}
b = {2, 3, 4}
print(a.intersection(b))
# Out:
# {2, 3}

# %%
#Q21  Write a code to create a dictionary with the keys "name", "age", and "city", and print it ?
person = {"name": "John", "age": 25, "city": "New York"}
print(person)
# Out:
# {'name': 'John', 'age': 25, 'city': 'New York'}

# %%
#Q22  Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25} ?
info = {'name': 'John', 'age': 25}
info["country"] = "USA"
print(info)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
#Q23 Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30} ?
person = {'name': 'Alice', 'age': 30}
print(person["name"])
# Out:
# Alice

# %%
#Q24 Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'} ?
person = {'name': 'Bob', 'age': 22, 'city': 'New York'}
del person["age"]
print(person)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
#Q25 5. Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'} ?
person = {'name': 'Alice', 'city': 'Paris'}
print("city" in person)
# Out:
# True

# %%
#Q26 Write a code to create a list, a tuple, and a dictionary, and print them all ?
my_list = [1, 2, 3]
my_tuple = (4, 5, 6)
my_dict = {"a": 1, "b": 2}
print(my_list)
print(my_tuple)
print(my_dict)
# Out:
# [1, 2, 3]
# (4, 5, 6)
# {'a': 1, 'b': 2}

# %%
#Q27 Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.(replaced)?
import random
numbers = random.sample(range(1, 101), 5)
numbers.sort()
print(numbers)
# Out:
# [2, 35, 45, 62, 77]

# %%
#Q28  Write a code to create a list with strings and print the element at the third index ?
words = ["apple", "banana", "cherry", "date", "fig"]
print(words[3])
# Out:
# date

# %%
#Q29  Write a code to combine two dictionaries into one and print the result?
dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}
combined = {**dict1, **dict2}
print(combined)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
#Q30 Write a code to convert a list of strings into a set ?
words = ["apple", "banana", "cherry", "apple"]
unique_words = set(words)
print(unique_words)
# Out:
# {'apple', 'cherry', 'banana'}
